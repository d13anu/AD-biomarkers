# %%
# Importing the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
exp = pd.read_csv('SourceData/ADNI_meta_expression_data.csv')
exp
# Out:
#       RID   EXAMDATE     GUSPECID VISCODE2 Metabolon_Barcode       X35  \
# 0    4521   3/2/2012  GA808GNH-05       bl        FS20155058  1.508153
# 1    4488  2/23/2012  EA808GPZ-05       bl        FS20155059  1.304945
# 2    4516  2/28/2012  AA808GRC-05       bl        FS20155060  1.497896
# 3    4530  2/22/2012  FA808GSR-05       bl        FS20155061  0.735734
# 4    4462  2/28/2012  JA808GV2-04       bl        FS20155062  1.585359
# ..    ...        ...          ...      ...               ...       ...
# 682   459   5/8/2006  GA801845-12       bl        FS19058971  0.891288
# 683   150   3/8/2006  HA80185C-13       bl        FS19058972  1.093903
# 684   448  5/15/2006  AA8018BB-16       bl        FS19058973  0.821804
# 685   190  5/16/2006  EA8018CJ-15       bl        FS19058974  1.028117
# 686   321  4/19/2006  GA8018H7-11       bl        FS19058976  1.399174
#
#           X41       X50       X55       X92  ...  X999925271  X999925422  \
# 0    1.730385  0.612859  1.700089  1.319669  ...    0.027190    1.264136
# 1    0.769849  0.964105  2.366413  0.413992  ...    1.206788    1.481716
# 2    0.180502  1.672050  0.801656  1.008023  ...    0.890854    1.095188
# 3    0.629868  1.340150  0.697065  0.076045  ...    0.027190    0.763008
# 4    0.823736  0.830875  1.176043  0.926530  ...    0.159002    0.851596
# ..        ...       ...       ...       ...  ...         ...         ...
# 682  1.108556  0.667609  1.944946  0.076045  ...    0.201674    1.921967
# 683  1.110865  2.522237  4.001797  2.486405  ...    0.027190    2.083849
# 684  0.321656  0.348298  0.574775  0.858026  ...    2.397347    1.199610
# 685  1.207298  0.793392  2.217697  1.667094  ...    4.105037    0.659952
# 686  1.143413  1.868921  3.849212  1.120105  ...    0.521007    2.318796
#
#      X999925520  X999925790  X999925855  X999925936  X999925948  X999925957  \
# 0      1.652838    0.963741    1.602593    1.337484    1.213671    0.806887
# 1      1.868413    0.566691         NaN    0.997846    1.135958    1.009465
# 2      1.285440    0.645923    0.875486    1.089542    1.084168    1.091710
# 3      1.485588    0.931784    0.866102    0.796483    0.606605    1.301205
# 4      1.280229    0.794974    1.045853    0.995122    0.870984    1.088682
# ..          ...         ...         ...         ...         ...         ...
# 682    0.510384    1.323597    0.883226         NaN    1.948850    0.974705
# 683    2.568156    1.177244    2.558125         NaN         NaN    1.617158
# 684    1.361833    0.746492    0.414803    0.941105    0.668174    0.705114
# 685    0.492338    0.430374         NaN         NaN    1.446751    1.959232
# 686    0.868961    0.630491    1.183140         NaN    1.320337    1.987913
#
#      X999925983  X999926062
# 0      1.546207    0.333502
# 1      0.692076    0.926831
# 2      0.615039    0.330528
# 3      0.436644    2.565797
# 4      0.799060    3.141871
# ..          ...         ...
# 682    0.815341    1.225030
# 683    2.532791    0.397648
# 684    0.432982    1.532889
# 685    0.576301    4.084813
# 686    1.300872    0.040757
#
# [687 rows x 461 columns]

# %%
info = pd.read_csv('SourceData/ADNI_meta_info.csv')
info
# Out:
#        CHEM_ID           SUPER_PATHWAY  \
# 0           35              Amino Acid
# 1           41              Amino Acid
# 2           50              Amino Acid
# 3           55  Cofactors and Vitamins
# 4           92              Amino Acid
# ..         ...                     ...
# 451  999925936                     NaN
# 452  999925948                     NaN
# 453  999925957                     NaN
# 454  999925983                     NaN
# 455  999926062                     NaN
#
#                                 SUB_PATHWAY  PATHWAY_SORTORDER     TYPE  \
# 0                      Glutamate Metabolism               62.0    NAMED
# 1                      Histidine Metabolism               85.0    NAMED
# 2                      Polyamine Metabolism              545.0    NAMED
# 3    Nicotinate and Nicotinamide Metabolism             4317.0    NAMED
# 4                         Lysine Metabolism              125.0    NAMED
# ..                                      ...                ...      ...
# 451                                     NaN                NaN  UNNAMED
# 452                                     NaN                NaN  UNNAMED
# 453                                     NaN                NaN  UNNAMED
# 454                                     NaN                NaN  UNNAMED
# 455                                     NaN                NaN  UNNAMED
#
#                         INCHIKEY                         SMILES  \
# 0    DWAKNKKXGALPNW-UHFFFAOYSA-N                 OC(C1CCC=N1)=O
# 1    CCLQKVKJOGVQLU-UHFFFAOYSA-N  NCCCC(NC(CC1=CN=CN1)C(O)=O)=O
# 2    ATHGHQPFGPMSJY-UHFFFAOYSA-N                     NCCCCNCCCN
# 3    LDHMAVIPBRSVRG-UHFFFAOYSA-N    C[N+]1=CC(C([NH-])=O)=CC=C1
# 4    FGSBNBBHOZHUBO-UHFFFAOYSA-N           OC(C(CCCC(O)=O)=O)=O
# ..                           ...                            ...
# 451                          NaN                            NaN
# 452                          NaN                            NaN
# 453                          NaN                            NaN
# 454                          NaN                            NaN
# 455                          NaN                            NaN
#
#                    CHEMICAL_NAME                    PLOT_NAME        CAS  \
# 0    S-1-pyrroline-5-carboxylate  S-1-pyrroline-5-carboxylate  2906-39-0
# 1                  homocarnosine                homocarnosine  3650-73-5
# 2                     spermidine                   spermidine   124-20-9
# 3           1-methylnicotinamide         1-methylnicotinamide  1005-24-9
# 4                   2-oxoadipate                 2-oxoadipate  3184-35-8
# ..                           ...                          ...        ...
# 451                      X-25936                      X-25936        NaN
# 452                      X-25948                      X-25948        NaN
# 453                      X-25957                      X-25957        NaN
# 454                      X-25983                      X-25983        NaN
# 455                      X-26062                      X-26062        NaN
#
#      CHEMSPIDER         HMDB    KEGG       PUBCHEM  COMP_ID  LIB_ID  \
# 0    10140206.0  HMDB0001301  C04322  1.196618e+07    42370     400
# 1     8418848.0  HMDB0000745  C00884  8.923510e+12     1633     209
# 2        1071.0  HMDB0001257  C00315  1.102000e+03      485     402
# 3     8305504.0  HMDB0000699  C02918  4.570000e+02    27665     400
# 4          70.0  HMDB0000225  C00322  7.100000e+01    38347     209
# ..          ...          ...     ...           ...      ...     ...
# 451         NaN          NaN     NaN           NaN    63840     400
# 452         NaN          NaN     NaN           NaN    63899     400
# 453         NaN          NaN     NaN           NaN    63908     400
# 454         NaN          NaN     NaN           NaN    63973     400
# 455         NaN          NaN     NaN           NaN    64337     209
#
#      CHRO_LIB_ENTRY_ID   PLATFORM      ChemID
# 0               166164  Pos Early         X35
# 1               150339        Neg         X41
# 2               157851   Pos Late         X50
# 3               155829  Pos Early         X55
# 4               141864        Neg         X92
# ..                 ...        ...         ...
# 451             223405  Pos Early  X999925936
# 452             223706  Pos Early  X999925948
# 453             223734  Pos Early  X999925957
# 454             224190  Pos Early  X999925983
# 455             237366        Neg  X999926062
#
# [456 rows x 19 columns]

# %% [markdown]
# ## Explore data

# %%
print(exp.value_counts(['RID']))
print(exp.value_counts(['VISCODE2']))
# Out:
# RID
# 388     2
# 1016    2
# 3       1
# 4346    1
# 4324    1
#        ..
# 1304    1
# 1315    1
# 1321    1
# 1334    1
# 5058    1
# Name: count, Length: 685, dtype: int64
# VISCODE2
# bl          658
# m60           8
# m24           5
# m36           5
# m48           4
# m72           3
# Name: count, dtype: int64

# %%
# Only baseline data
print("original shape",exp.shape)
exp_bl = exp[exp['VISCODE2']=='bl']
print("only baseline", exp_bl.shape)

# Get ChemID with most missing vales
print("\n\nmeta with missing vals:\n", exp_bl.isnull().sum().sort_values(ascending=False))

# get samples with most missing values
print("\n\nsamples with missing vals:\n",exp_bl.isnull().sum(axis=1).sort_values(ascending=False))
# Out:
# original shape (687, 461)
# only baseline (658, 461)
#
#
# meta with missing vals:
#  X100002809    657
# X100020805    657
# X100006381    654
# X100002806    651
# X100002715    648
#              ...
# EXAMDATE        0
# X100001296      0
# X100001251      0
# X100001178      0
# X999926062      0
# Length: 461, dtype: int64
#
#
# samples with missing vals:
#  683    178
# 661    123
# 484    106
# 664    103
# 665    100
#       ...
# 594     29
# 20      29
# 483     28
# 459     28
# 69      27
# Length: 658, dtype: int64

# %%
# drop missing vales columns and rows
# Compounds with more than 20% missing values
exp_bl = exp_bl.dropna(thresh=exp_bl.shape[0] * 0.8, axis=1)

# samples with more than 10% values
exp_bl = exp_bl.dropna(thresh=exp_bl.shape[1] * 0.9, axis=0)

print("\n\nsamples with missing vals:\n",exp_bl.isnull().sum(axis=1).sort_values(ascending=False))
# Out:
# samples with missing vals:
#  508    41
# 339    40
# 252    40
# 427    40
# 657    40
#        ..
# 344     2
# 521     1
# 107     1
# 347     0
# 0       0
# Length: 620, dtype: int64

# %%
exp_bl
# Out:
#       RID    EXAMDATE     GUSPECID VISCODE2 Metabolon_Barcode       X35  \
# 0    4521    3/2/2012  GA808GNH-05       bl        FS20155058  1.508153
# 1    4488   2/23/2012  EA808GPZ-05       bl        FS20155059  1.304945
# 2    4516   2/28/2012  AA808GRC-05       bl        FS20155060  1.497896
# 3    4530   2/22/2012  FA808GSR-05       bl        FS20155061  0.735734
# 4    4462   2/28/2012  JA808GV2-04       bl        FS20155062  1.585359
# ..    ...         ...          ...      ...               ...       ...
# 679   892  10/24/2006  EA8017V0-10       bl        FS19058968  1.051325
# 680  1290   2/27/2007  JA801818-15       bl        FS19058969  0.517652
# 681   438    5/9/2006  KA80182Q-11       bl        FS19058970  0.764282
# 682   459    5/8/2006  GA801845-12       bl        FS19058971  0.891288
# 684   448   5/15/2006  AA8018BB-16       bl        FS19058973  0.821804
#
#           X41       X50       X55       X92  ...  X999925271  X999925422  \
# 0    1.730385  0.612859  1.700089  1.319669  ...    0.027190    1.264136
# 1    0.769849  0.964105  2.366413  0.413992  ...    1.206788    1.481716
# 2    0.180502  1.672050  0.801656  1.008023  ...    0.890854    1.095188
# 3    0.629868  1.340150  0.697065  0.076045  ...    0.027190    0.763008
# 4    0.823736  0.830875  1.176043  0.926530  ...    0.159002    0.851596
# ..        ...       ...       ...       ...  ...         ...         ...
# 679  1.020450  1.588228  1.442580  1.260183  ...    1.691782    1.024137
# 680  1.392305  0.308009  0.764881  1.355179  ...    0.925309    0.944639
# 681  1.990539  1.123101  0.904406  0.076045  ...    0.027190    1.779424
# 682  1.108556  0.667609  1.944946  0.076045  ...    0.201674    1.921967
# 684  0.321656  0.348298  0.574775  0.858026  ...    2.397347    1.199610
#
#      X999925520  X999925790  X999925855  X999925936  X999925948  X999925957  \
# 0      1.652838    0.963741    1.602593    1.337484    1.213671    0.806887
# 1      1.868413    0.566691         NaN    0.997846    1.135958    1.009465
# 2      1.285440    0.645923    0.875486    1.089542    1.084168    1.091710
# 3      1.485588    0.931784    0.866102    0.796483    0.606605    1.301205
# 4      1.280229    0.794974    1.045853    0.995122    0.870984    1.088682
# ..          ...         ...         ...         ...         ...         ...
# 679    1.179237    0.847382    1.155053    1.168762    1.733302    1.591255
# 680    2.588135    1.358625    0.659793    1.707127    1.216675    0.952669
# 681    0.675041    1.853300    0.782381    1.370127    1.841979    0.807575
# 682    0.510384    1.323597    0.883226         NaN    1.948850    0.974705
# 684    1.361833    0.746492    0.414803    0.941105    0.668174    0.705114
#
#      X999925983  X999926062
# 0      1.546207    0.333502
# 1      0.692076    0.926831
# 2      0.615039    0.330528
# 3      0.436644    2.565797
# 4      0.799060    3.141871
# ..          ...         ...
# 679    0.736124    0.040757
# 680    1.272200    5.984177
# 681    0.741486    0.040757
# 682    0.815341    1.225030
# 684    0.432982    1.532889
#
# [620 rows x 413 columns]

# %% [markdown]
# ## Normalization and Proprocessing

# %% [markdown]
# Reference: ADNI_CruchagaLab_CSF_Metabolon_Metabolomic_Data_20230817.pdf
#
# *Located in: ../Articles*

# %%
## Transforming, normalizing and standardizing the data
comp_cols = [col for col in exp_bl.columns if col.startswith('X')]

# Apply natural log transformation
exp_bl[comp_cols] = exp_bl[comp_cols].apply(np.log)

# Drop non-essential columns
exp_data_final = exp_bl.drop(['EXAMDATE', 'GUSPECID',
                                'VISCODE2', 'Metabolon_Barcode'], axis=1)
exp_data_final
# Out:
#       RID       X35       X41       X50       X55       X92       X93  \
# 0    4521  0.410886  0.548344 -0.489621  0.530681  0.277381  0.419404
# 1    4488  0.266161 -0.261561 -0.036555  0.861375 -0.881908  0.124714
# 2    4516  0.404061 -1.712014  0.514051 -0.221075  0.007991 -0.136885
# 3    4530 -0.306887 -0.462245  0.292781 -0.360877 -2.576432 -0.796280
# 4    4462  0.460811 -0.193905 -0.185276  0.162156 -0.076309 -0.237305
# ..    ...       ...       ...       ...       ...       ...       ...
# 679   892  0.050051  0.020243  0.462619  0.366433  0.231257  0.521502
# 680  1290 -0.658452  0.330960 -1.177626 -0.268035  0.303933 -0.250226
# 681   438 -0.268818  0.688406  0.116094 -0.100477 -2.576432  0.063462
# 682   459 -0.115088  0.103058 -0.404052  0.665234 -2.576432  0.564138
# 684   448 -0.196254 -1.134273 -1.054695 -0.553776 -0.153121 -0.185900
#
#           X98      X111      X112  ...  X999925271  X999925422  X999925520  \
# 0    0.134547  0.089661  0.245456  ...   -3.604906    0.234389    0.502494
# 1   -0.082595  0.289187  0.055285  ...    0.187962    0.393201    0.625089
# 2   -0.285586 -0.303876 -0.159152  ...   -0.115575    0.090926    0.251101
# 3   -0.482040 -0.010632 -0.603761  ...   -3.604906   -0.270487    0.395811
# 4   -0.832453 -0.020162 -0.194910  ...   -1.838839   -0.160643    0.247039
# ..        ...       ...       ...  ...         ...         ...         ...
# 679 -0.416297 -0.061603  0.224230  ...    0.525783    0.023850    0.164868
# 680  0.683088 -0.136982 -0.037005  ...   -0.077627   -0.056953    0.950938
# 681  0.421020  0.015942 -0.032027  ...   -3.604906    0.576290   -0.392982
# 682  0.857658  0.446094  0.472714  ...   -1.601105    0.653349   -0.672593
# 684 -1.747602 -0.259950 -0.510973  ...    0.874363    0.181996    0.308832
#
#      X999925790  X999925855  X999925936  X999925948  X999925957  X999925983  \
# 0     -0.036932    0.471623    0.290790    0.193650   -0.214571    0.435805
# 1     -0.567941         NaN   -0.002156    0.127477    0.009421   -0.368060
# 2     -0.437075   -0.132976    0.085757    0.080813    0.087746   -0.486070
# 3     -0.070654   -0.143753   -0.227549   -0.499878    0.263290   -0.828637
# 4     -0.229446    0.044833   -0.004890   -0.138131    0.084968   -0.224319
# ..          ...         ...         ...         ...         ...         ...
# 679   -0.165604    0.144147    0.155945    0.550028    0.464523   -0.306357
# 680    0.306473   -0.415830    0.534812    0.196122   -0.048488    0.240748
# 681    0.616968   -0.245413    0.314903    0.610841   -0.213719   -0.299099
# 682    0.280353   -0.124174         NaN    0.667239   -0.025620   -0.204149
# 684   -0.292370   -0.879952   -0.060701   -0.403206   -0.349396   -0.837058
#
#      X999926062
# 0     -1.098107
# 1     -0.075985
# 2     -1.107063
# 3      0.942269
# 4      1.144818
# ..          ...
# 679   -3.200134
# 680    1.789119
# 681   -3.200134
# 682    0.202966
# 684    0.427154
#
# [620 rows x 409 columns]

# %%
# Replacing the remaining NaN expression values with the average of the column
exp_data_final = exp_data_final.fillna(exp_data_final.drop(['RID'], axis=1).mean())

exp_data_final
# Out:
#       RID       X35       X41       X50       X55       X92       X93  \
# 0    4521  0.410886  0.548344 -0.489621  0.530681  0.277381  0.419404
# 1    4488  0.266161 -0.261561 -0.036555  0.861375 -0.881908  0.124714
# 2    4516  0.404061 -1.712014  0.514051 -0.221075  0.007991 -0.136885
# 3    4530 -0.306887 -0.462245  0.292781 -0.360877 -2.576432 -0.796280
# 4    4462  0.460811 -0.193905 -0.185276  0.162156 -0.076309 -0.237305
# ..    ...       ...       ...       ...       ...       ...       ...
# 679   892  0.050051  0.020243  0.462619  0.366433  0.231257  0.521502
# 680  1290 -0.658452  0.330960 -1.177626 -0.268035  0.303933 -0.250226
# 681   438 -0.268818  0.688406  0.116094 -0.100477 -2.576432  0.063462
# 682   459 -0.115088  0.103058 -0.404052  0.665234 -2.576432  0.564138
# 684   448 -0.196254 -1.134273 -1.054695 -0.553776 -0.153121 -0.185900
#
#           X98      X111      X112  ...  X999925271  X999925422  X999925520  \
# 0    0.134547  0.089661  0.245456  ...   -3.604906    0.234389    0.502494
# 1   -0.082595  0.289187  0.055285  ...    0.187962    0.393201    0.625089
# 2   -0.285586 -0.303876 -0.159152  ...   -0.115575    0.090926    0.251101
# 3   -0.482040 -0.010632 -0.603761  ...   -3.604906   -0.270487    0.395811
# 4   -0.832453 -0.020162 -0.194910  ...   -1.838839   -0.160643    0.247039
# ..        ...       ...       ...  ...         ...         ...         ...
# 679 -0.416297 -0.061603  0.224230  ...    0.525783    0.023850    0.164868
# 680  0.683088 -0.136982 -0.037005  ...   -0.077627   -0.056953    0.950938
# 681  0.421020  0.015942 -0.032027  ...   -3.604906    0.576290   -0.392982
# 682  0.857658  0.446094  0.472714  ...   -1.601105    0.653349   -0.672593
# 684 -1.747602 -0.259950 -0.510973  ...    0.874363    0.181996    0.308832
#
#      X999925790  X999925855  X999925936  X999925948  X999925957  X999925983  \
# 0     -0.036932    0.471623    0.290790    0.193650   -0.214571    0.435805
# 1     -0.567941   -0.088230   -0.002156    0.127477    0.009421   -0.368060
# 2     -0.437075   -0.132976    0.085757    0.080813    0.087746   -0.486070
# 3     -0.070654   -0.143753   -0.227549   -0.499878    0.263290   -0.828637
# 4     -0.229446    0.044833   -0.004890   -0.138131    0.084968   -0.224319
# ..          ...         ...         ...         ...         ...         ...
# 679   -0.165604    0.144147    0.155945    0.550028    0.464523   -0.306357
# 680    0.306473   -0.415830    0.534812    0.196122   -0.048488    0.240748
# 681    0.616968   -0.245413    0.314903    0.610841   -0.213719   -0.299099
# 682    0.280353   -0.124174   -0.007530    0.667239   -0.025620   -0.204149
# 684   -0.292370   -0.879952   -0.060701   -0.403206   -0.349396   -0.837058
#
#      X999926062
# 0     -1.098107
# 1     -0.075985
# 2     -1.107063
# 3      0.942269
# 4      1.144818
# ..          ...
# 679   -3.200134
# 680    1.789119
# 681   -3.200134
# 682    0.202966
# 684    0.427154
#
# [620 rows x 409 columns]

# %%
meta_data = pd.read_csv('SourceData/prot_exp_data.csv')[['RID', 'DX.bl', 'AGE', 'PTGENDER', 'APOE4', 'PTEDUCAT']]
meta_data
# Out:
#       RID DX.bl   AGE PTGENDER  APOE4  PTEDUCAT
# 0    4521   MCI  70.0     Male    1.0      18.0
# 1    4488    CN  72.6     Male    0.0      18.0
# 2    4516    CN  71.4     Male    0.0      20.0
# 3    4530   MCI  75.9     Male    1.0      18.0
# 4    4462   MCI  71.3     Male    0.0      18.0
# ..    ...   ...   ...      ...    ...       ...
# 703   886    CN  71.3   Female    0.0      15.0
# 704   336   MCI  76.1     Male    1.0      17.0
# 705   588   MCI  64.6     Male    2.0      14.0
# 706   973   MCI  76.8     Male    0.0      20.0
# 707  1161    AD  79.8     Male    0.0      16.0
#
# [708 rows x 6 columns]

# %%
exp_data_csv = pd.merge(exp_data_final, meta_data, on='RID', how='left')

# %%
exp_data_csv.to_csv('SourceData/meta_exp_data.csv', index=False)

# %% [markdown]
# ## Plots

# %%
exp_data_final = exp_data_final.set_index('RID')
exp_data_final
# Out:
#            X35       X41       X50       X55       X92       X93       X98  \
# RID
# 4521  0.410886  0.548344 -0.489621  0.530681  0.277381  0.419404  0.134547
# 4488  0.266161 -0.261561 -0.036555  0.861375 -0.881908  0.124714 -0.082595
# 4516  0.404061 -1.712014  0.514051 -0.221075  0.007991 -0.136885 -0.285586
# 4530 -0.306887 -0.462245  0.292781 -0.360877 -2.576432 -0.796280 -0.482040
# 4462  0.460811 -0.193905 -0.185276  0.162156 -0.076309 -0.237305 -0.832453
# ...        ...       ...       ...       ...       ...       ...       ...
# 892   0.050051  0.020243  0.462619  0.366433  0.231257  0.521502 -0.416297
# 1290 -0.658452  0.330960 -1.177626 -0.268035  0.303933 -0.250226  0.683088
# 438  -0.268818  0.688406  0.116094 -0.100477 -2.576432  0.063462  0.421020
# 459  -0.115088  0.103058 -0.404052  0.665234 -2.576432  0.564138  0.857658
# 448  -0.196254 -1.134273 -1.054695 -0.553776 -0.153121 -0.185900 -1.747602
#
#           X111      X112      X117  ...  X999925271  X999925422  X999925520  \
# RID                                 ...
# 4521  0.089661  0.245456  0.309168  ...   -3.604906    0.234389    0.502494
# 4488  0.289187  0.055285 -0.227944  ...    0.187962    0.393201    0.625089
# 4516 -0.303876 -0.159152 -0.539722  ...   -0.115575    0.090926    0.251101
# 4530 -0.010632 -0.603761 -0.839250  ...   -3.604906   -0.270487    0.395811
# 4462 -0.020162 -0.194910 -0.386753  ...   -1.838839   -0.160643    0.247039
# ...        ...       ...       ...  ...         ...         ...         ...
# 892  -0.061603  0.224230  0.035008  ...    0.525783    0.023850    0.164868
# 1290 -0.136982 -0.037005  0.051770  ...   -0.077627   -0.056953    0.950938
# 438   0.015942 -0.032027  0.159087  ...   -3.604906    0.576290   -0.392982
# 459   0.446094  0.472714  0.150799  ...   -1.601105    0.653349   -0.672593
# 448  -0.259950 -0.510973 -1.114819  ...    0.874363    0.181996    0.308832
#
#       X999925790  X999925855  X999925936  X999925948  X999925957  X999925983  \
# RID
# 4521   -0.036932    0.471623    0.290790    0.193650   -0.214571    0.435805
# 4488   -0.567941   -0.088230   -0.002156    0.127477    0.009421   -0.368060
# 4516   -0.437075   -0.132976    0.085757    0.080813    0.087746   -0.486070
# 4530   -0.070654   -0.143753   -0.227549   -0.499878    0.263290   -0.828637
# 4462   -0.229446    0.044833   -0.004890   -0.138131    0.084968   -0.224319
# ...          ...         ...         ...         ...         ...         ...
# 892    -0.165604    0.144147    0.155945    0.550028    0.464523   -0.306357
# 1290    0.306473   -0.415830    0.534812    0.196122   -0.048488    0.240748
# 438     0.616968   -0.245413    0.314903    0.610841   -0.213719   -0.299099
# 459     0.280353   -0.124174   -0.007530    0.667239   -0.025620   -0.204149
# 448    -0.292370   -0.879952   -0.060701   -0.403206   -0.349396   -0.837058
#
#       X999926062
# RID
# 4521   -1.098107
# 4488   -0.075985
# 4516   -1.107063
# 4530    0.942269
# 4462    1.144818
# ...          ...
# 892    -3.200134
# 1290    1.789119
# 438    -3.200134
# 459     0.202966
# 448     0.427154
#
# [620 rows x 408 columns]

# %%
fig = plt.figure(figsize =(25, 7))
pd.DataFrame.boxplot(exp_data_final)
# Out:
# <Axes: >

# %%
vars = pd.DataFrame.var(exp_data_final).sort_values(ascending=False)
means = pd.DataFrame.mean(exp_data_final).sort_values(ascending=False)
std = pd.DataFrame.std(exp_data_final).sort_values(ascending=False)
# Combine into a single DataFrame
stats_df = pd.DataFrame({
    'variance': vars,
    'mean': means,
    'std': std
}).sort_values(by='std', ascending=False)

# Plot
stats_df.plot(y=['variance', 'mean', 'std'], figsize=(20, 10))
plt.tight_layout()
plt.show()
